# %%
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('img.jpeg')
print(img)
# Out:
# [[[226 230 235]
#   [226 230 235]
#   [226 230 235]
#   ...
#   [175 172 167]
#   [167 164 159]
#   [157 155 147]]
#
#  [[225 229 234]
#   [225 229 234]
#   [225 229 234]
#   ...
#   [159 156 148]
#   [150 148 138]
#   [140 138 128]]
#
#  [[222 228 235]
#   [222 228 235]
#   [222 228 235]
#   ...
#   [149 146 132]
#   [140 137 122]
#   [133 128 113]]
#
#  ...
#
#  [[129 121  68]
#   [127 122  67]
#   [119 118  58]
#   ...
#   [101  96  35]
#   [110 105  44]
#   [102  96  37]]
#
#  [[129 124  69]
#   [126 122  64]
#   [115 114  54]
#   ...
#   [100  95  34]
#   [106 100  41]
#   [ 95  91  33]]
#
#  [[128 123  68]
#   [123 119  61]
#   [113 112  52]
#   ...
#   [101  95  36]
#   [105  99  40]
#   [ 95  91  33]]]

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
plt.imshow(img)

# %%
img = cv2.imread("img.jpeg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2HLS)
plt.imshow(img)

# %% [markdown]
# Blending and Pasting images
# For some comp vision systems, we'll want to be able

# %%
#Two images
img1 = cv2.imread("C:/2-compVision/dog_backpack.jpg")
img2 = cv2.imread("C:/2-compVision/watermark_no_copy.png")

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1 = cv2.resize(img1,(1200,1200))
img2 = cv2.resize(img2,(1200,1200))

# %%
img2.shape
# Out:
# (1200, 1200, 3)

# %%
blended = cv2.addWeighted(src1=img1,alpha=0.7,src2=img2,beta=0.3,gamma=0)
plt.imshow(blended)

# %% [markdown]
# Thresholding in image processing is a commomly used technique that involves converting an image
# into a binary image by seperating the pixel into two classes based on their

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
img = cv2.imread("rainbow.jpg")

# %%
plt.imshow(img)

# %%
img = cv2.imread("rainbow.jpg",0)
plt.imshow(img,cmap='gray')

# %%
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
plt.imshow(thresh1,cmap='gray')

# %%
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
plt.imshow(thresh2,cmap='gray')

# %%
ret
# Out:
# 127.0

# %%
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
plt.imshow(thresh3,cmap='gray')

# %%
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
plt.imshow(thresh4,cmap='gray')

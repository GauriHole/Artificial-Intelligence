# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
full = cv2.imread('sammy.jpg')
full = cv2.cvtColor(full,cv2.COLOR_BGR2RGB)
plt.imshow(full)

# %%
full.shape
# Out:
# (1367, 1025, 3)

# %%
face = cv2.imread('sammy_face.jpg')
face = cv2.cvtColor(face,cv2.COLOR_BGR2RGB)
plt.imshow(face)

# %%
# Correct code
total = [1, 2, 3]  # Rename the variable to avoid conflict
print(sum(total))  # Now sum() works correctly as a function
# Out:
# 6

# %%
mystring = 'sum'

# %%
mystring([1,2,3])
eval(mystring)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 mystring([1,2,3])
#       2 eval(mystring)
#
# TypeError: 'str' object is not callable

# %%
import cv2
cap = cv2.VideoCapture(0)

#Automatically grab width and height from video feed
#(Return float  which we need to convert to integer from later on)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

x = width//2
y = height//2
#width and height adding 1/4 of width and height from the center.
w = width//4
h = height//4
while True:
    #capture frame-by-frame
    ret,frame = cap.read()
    #Draw a rectangle on stream
    cv2.rectangle(frame,(x,y),(x+w, y+h), color=(0,0,255),thickness=4)
    #Display the resulting frame 
    cv2.imshow('frame',frame)
    if cv2.waitKey(1)&0xFF == ord('q'):
        break
#when everything is done , release the capture
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

full = cv2.imread("sammy.jpg")
full = cv2.cvtColor(full,cv2.COLOR_BGR2RGB)

face = cv2.imread('sammy_face.jpg')
face = cv2.cvtColor(face,cv2.COLOR_BGR2RGB)

methods = ['cv2.TM_CCOEFF','cv2.TM_CCOEFF_NORMED','cv2.TM_CCORR','cv2.CCORR_NORMED','cv2.TM_SQDTFF','cv2.TM_SQDIF_NORMED']

for m in methods:
    full_copy = full.copy()
    method = eval(m)
    res = cv2.matchTemplate(full_copy,face,method)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
    
    #Set up drawing of Rectangle
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right=(top_left[0]+width,top_left[1]+height)
    cv2.rectangle(full_copy,top_left,bottom_right,255,10)
    plt.subplot(121)
    plt.imshow(res)
    plt.title('Result of Template Matching')
    
    plt.subplot(122)
    plt.imshow(full_copy)
    plt.title('Detected Point')
    plt.suptitle(m)
    
    plt.show()
    print('\n')
    print('\n')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 16
#      14 for m in methods:
#      15     full_copy = full.copy()
# ---> 16     method = eval(m)
#      17     res = cv2.matchTemplate(full_copy,face,method)
#      18     min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
#
# File <string>:1
#
# AttributeError: module 'cv2' has no attribute 'CCORR_NORMED'
